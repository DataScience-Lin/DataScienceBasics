# %%
import pandas as pd
import numpy as np

# %%
## load the data

df = pd.read_csv("D:\\SimpliLearn\\wine.csv")

# %%
### dataframe

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df["fixed acidity"].dtype
# Out:
# dtype('float64')

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
## change datatype

df["quality"] = df["quality"].astype("category")

# %%
df.dtypes
# Out:
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                 category
# dtype: object

# %%
### check for missing values

df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
### laod teh data

df = pd.read_csv("D:\\SimpliLearn\\Machine Learning\\Assisted Practice\\Lesson 3\\train.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
### drop the variable

df = df.drop("Cabin", axis=1)

# %%
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
df = df.drop(["Fare", "Sex"], axis=1)

# %%
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Embarked        0.224467
# dtype: float64

# %%
### cehck th distribution of varaible
import seaborn as sns

sns.distplot(df["Age"])

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000

# %%
df["Age"] = df["Age"].fillna(29.6)

# %%
df.isnull().sum()/len(df)*100
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Age            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Embarked       0.224467
# dtype: float64

# %%
### shape
df.shape
# Out:
# (891, 9)

# %%
df["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
col = df["Survived"].value_counts()
df["freq_count"] = df["Survived"].map(col)

# %%
df["freq_count"].head()
# Out:
# 0    549
# 1    342
# 2    342
# 3    342
# 4    549
# Name: freq_count, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket Embarked  freq_count
# 0         A/5 21171        S         549
# 1          PC 17599        C         342
# 2  STON/O2. 3101282        S         342
# 3            113803        S         342
# 4            373450        S         549

# %%
df.loc[2:5, "Age"]
# Out:
# 2    26.0
# 3    35.0
# 4    35.0
# 5    29.6
# Name: Age, dtype: float64

# %%
df.iloc[2:5, 3]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
### extracting the data

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket Embarked  freq_count
# 0         A/5 21171        S         549
# 1          PC 17599        C         342
# 2  STON/O2. 3101282        S         342
# 3            113803        S         342
# 4            373450        S         549

# %%
df[df["Survived"]==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
cond1  = df["Survived"]==1
cond2  = df["Pclass"]==3

df[cond1 & cond2]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 838          839         1       3
# 855          856         1       3
# 858          859         1       3
# 869          870         1       3
# 875          876         1       3
#
#                                                   Name   Age  SibSp  Parch  \
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 10                     Sandstrom, Miss. Marguerite Rut   4.0      1      1
# 19                             Masselmani, Mrs. Fatima  29.6      0      0
# 22                         McGowan, Miss. Anna "Annie"  15.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
### Correaltion

df.corr()*100
# Out:
#              PassengerId    Survived      Pclass         Age       SibSp  \
# PassengerId   100.000000   -0.500666   -3.514399    3.326777   -5.752683
# Survived       -0.500666  100.000000  -33.848104   -6.952761   -3.532250
# Pclass         -3.514399  -33.848104  100.000000  -33.186352    8.308136
# Age             3.326777   -6.952761  -33.186352  100.000000  -23.268120
# SibSp          -5.752683   -3.532250    8.308136  -23.268120  100.000000
# Parch          -0.165201    8.162941    1.844267  -17.881240   41.483770
# freq_count      0.500666 -100.000000   33.848104    6.952761    3.532250
#
#                   Parch  freq_count
# PassengerId   -0.165201    0.500666
# Survived       8.162941 -100.000000
# Pclass         1.844267   33.848104
# Age          -17.881240    6.952761
# SibSp         41.483770    3.532250
# Parch        100.000000   -8.162941
# freq_count    -8.162941  100.000000

# %%
from sklearn.impute import SimpleImputer

# %%
### laod teh data

df = pd.read_csv("D:\\SimpliLearn\\Machine Learning\\Assisted Practice\\Lesson 3\\train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
### laod data

df = pd.read_csv("D:\\SimpliLearn\\Machine Learning\\Assisted Practice\\Lesson 5\\horse.csv")

# %%
df.isnull().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# nasogastric_reflux_ph    246
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        165
# abdomo_protein           198
# outcome                    0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
df.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
miss = SimpleImputer(missing_values=np.nan, strategy="median")
#miss = SimpleImputer(missing_values=np.nan, strategy="most_frequent")  # string columns

# %%
miss_df = miss.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-e5521a4ce1ec> in <module>
# ----> 1 miss_df = miss.fit_transform(df)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     286         self : SimpleImputer
#     287         """
# --> 288         X = self._validate_input(X, in_fit=True)
#     289
#     290         # default fill_value is 0 for numerical input and "missing_value"
#
# ~\Anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
# ...

# %%
df_num = df.select_dtypes(exclude="object")

# %%
df_num.head()
# Out:
#    hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0           530101         38.5   66.0              28.0
# 1           534817         39.2   88.0              20.0
# 2           530334         38.3   40.0              24.0
# 3          5290409         39.1  164.0              84.0
# 4           530255         37.3  104.0              35.0
#
#    nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 0                    NaN                45.0            8.4             NaN
# 1                    NaN                50.0           85.0             2.0
# 2                    NaN                33.0            6.7             NaN
# 3                    5.0                48.0            7.2             5.3
# 4                    NaN                74.0            7.4             NaN
#
#    lesion_1  lesion_2  lesion_3
# 0     11300         0         0
# 1      2208         0         0
# 2         0         0         0
# ...

# %%
miss_df = miss.fit_transform(df_num)

# %%
miss_df
# Out:
# array([[5.30101e+05, 3.85000e+01, 6.60000e+01, ..., 1.13000e+04,
#         0.00000e+00, 0.00000e+00],
#        [5.34817e+05, 3.92000e+01, 8.80000e+01, ..., 2.20800e+03,
#         0.00000e+00, 0.00000e+00],
#        [5.30334e+05, 3.83000e+01, 4.00000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        ...,
#        [5.29386e+05, 3.75000e+01, 7.20000e+01, ..., 3.20500e+03,
#         0.00000e+00, 0.00000e+00],
#        [5.30612e+05, 3.65000e+01, 1.00000e+02, ..., 2.20800e+03,
#         0.00000e+00, 0.00000e+00],
#        [5.34618e+05, 3.72000e+01, 4.00000e+01, ..., 6.11200e+03,
#         0.00000e+00, 0.00000e+00]])

# %%
## convert array to dataframe

df_process = pd.DataFrame(miss_df, columns=df_num.columns)

# %%
df_process.head()
# Out:
#    hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0         530101.0         38.5   66.0              28.0
# 1         534817.0         39.2   88.0              20.0
# 2         530334.0         38.3   40.0              24.0
# 3        5290409.0         39.1  164.0              84.0
# 4         530255.0         37.3  104.0              35.0
#
#    nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 0                    5.0                45.0            8.4             2.3
# 1                    5.0                50.0           85.0             2.0
# 2                    5.0                33.0            6.7             2.3
# 3                    5.0                48.0            7.2             5.3
# 4                    5.0                74.0            7.4             2.3
#
#    lesion_1  lesion_2  lesion_3
# 0   11300.0       0.0       0.0
# 1    2208.0       0.0       0.0
# 2       0.0       0.0       0.0
# ...

# %%
df_process.isnull().sum()
# Out:
# hospital_number          0
# rectal_temp              0
# pulse                    0
# respiratory_rate         0
# nasogastric_reflux_ph    0
# packed_cell_volume       0
# total_protein            0
# abdomo_protein           0
# lesion_1                 0
# lesion_2                 0
# lesion_3                 0
# dtype: int64

# %%
### groupby

df = pd.read_csv("D:\\SimpliLearn\\Machine Learning\\Assisted Practice\\Lesson 3\\train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby("Survived")["Age"].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
df.groupby(["Survived", "Sex"])["Age"].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %%
df.groupby(["Survived", "Sex"])["Age"].median()
# Out:
# Survived  Sex
# 0         female    24.5
#           male      29.0
# 1         female    28.0
#           male      28.0
# Name: Age, dtype: float64

# %%
df.groupby(["Survived", "Sex"])["Age"].agg(["mean", "median", "count"])
# Out:
#                       mean  median  count
# Survived Sex
# 0        female  25.046875    24.5     64
#          male    31.618056    29.0    360
# 1        female  28.847716    28.0    197
#          male    27.276022    28.0     93

# %%
### box plot

sns.boxplot(df["Age"])

# %%
### concatenation

df1 = pd.DataFrame({"A":[1,2,3], "B":[7,8,9]})

# %%
df1
# Out:
#    A  B
# 0  1  7
# 1  2  8
# 2  3  9

# %%
df2 = pd.DataFrame({"A":[3,4], "C":[34,56]})

# %%
df2
# Out:
#    A   C
# 0  3  34
# 1  4  56

# %%
df3 = pd.concat([df1,df2])

# %%
df3
# Out:
#    A    B     C
# 0  1  7.0   NaN
# 1  2  8.0   NaN
# 2  3  9.0   NaN
# 0  3  NaN  34.0
# 1  4  NaN  56.0

# %%
df3 = pd.concat([df1,df2], ignore_index=True)

# %%
df3
# Out:
#    A    B     C
# 0  1  7.0   NaN
# 1  2  8.0   NaN
# 2  3  9.0   NaN
# 3  3  NaN  34.0
# 4  4  NaN  56.0

# %%
pd.concat([df1,df2], ignore_index=True, axis=1)
# Out:
#    0  1    2     3
# 0  1  7  3.0  34.0
# 1  2  8  4.0  56.0
# 2  3  9  NaN   NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.set_index("PassengerId")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
### Mergin

df1
# Out:
#    A  B
# 0  1  7
# 1  2  8
# 2  3  9

# %%
df2
# Out:
#    A   C
# 0  3  34
# 1  4  56

# %%
df1.merge(df2, on="A", how="inner")
# Out:
#    A  B   C
# 0  3  9  34

# %%
df1.merge(df2, on="A", how="outer")
# Out:
#    A    B     C
# 0  1  7.0   NaN
# 1  2  8.0   NaN
# 2  3  9.0  34.0
# 3  4  NaN  56.0

# %%
df1.merge(df2, on="A", how="left")
# Out:
#    A  B     C
# 0  1  7   NaN
# 1  2  8   NaN
# 2  3  9  34.0

# %%
df2.merge(df1, on="A", how="left")
# Out:
#    A   C    B
# 0  3  34  9.0
# 1  4  56  NaN

# %%
df2.merge(df1, on="A", how="right")
# Out:
#    A     C  B
# 0  3  34.0  9
# 1  1   NaN  7
# 2  2   NaN  8
